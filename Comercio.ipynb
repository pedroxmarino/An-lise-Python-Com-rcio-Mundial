# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from plotnine import * 
import geopandas as gpd

# %%
#Item a)
#Importação da base de dados wdi:
wdi = pd.read_csv(r'C:/Users/pedro/Desktop/Base Python/wdi.csv')
wdi
# Out:
#        countryname countrycode  \
# 0            Aruba         ABW
# 1            Aruba         ABW
# 2            Aruba         ABW
# 3            Aruba         ABW
# 4            Aruba         ABW
# ...            ...         ...
# 311824    Zimbabwe         ZWE
# 311825    Zimbabwe         ZWE
# 311826    Zimbabwe         ZWE
# 311827    Zimbabwe         ZWE
# 311828    Zimbabwe         ZWE
#
#                                             indicatorname  \
# 0       Logistics performance index: Competence and qu...
# 1       External debt stocks, private nonguaranteed (P...
# 2                      Time to resolve insolvency (years)
# 3       Level of water stress: freshwater withdrawal a...
# 4         Manufactures exports (% of merchandise exports)
# ...                                                   ...
# 311824  Educational attainment, Doctoral or equivalent...
# 311825      GNI per capita, PPP (current international $)
# 311826  Coverage of social insurance programs in 4th q...
# 311827  Informal payments to public officials (% of fi...
# 311828  Households and NPISHs final consumption expend...
#
#                   indicatorcode      v1960      v1961      v1962      v1963  \
# 0                LP.LPI.LOGS.XQ        NaN        NaN        NaN        NaN
# 1                DT.DOD.DPNG.CD        NaN        NaN        NaN        NaN
# 2                   IC.ISV.DURS        NaN        NaN        NaN        NaN
# 3                ER.H2O.FWST.ZS        NaN        NaN        NaN        NaN
# 4             TX.VAL.MANF.ZS.UN        NaN        NaN        NaN        NaN
# ...                         ...        ...        ...        ...        ...
# 311824        SE.TER.CUAT.DO.ZS        NaN        NaN        NaN        NaN
# 311825        NY.GNP.PCAP.PP.CD        NaN        NaN        NaN        NaN
# 311826  per_si_allsi.cov_q4_tot        NaN        NaN        NaN        NaN
# 311827           IC.FRM.CORR.ZS        NaN        NaN        NaN        NaN
# 311828           NE.CON.PRVT.ZS  77.626339  74.224942  74.144418  75.100027
#
#             v1964      v1965  ...        v2012        v2013        v2014  \
# 0             NaN        NaN  ...          NaN          NaN          NaN
# 1             NaN        NaN  ...          NaN          NaN          NaN
# 2             NaN        NaN  ...          NaN          NaN          NaN
# 3             NaN        NaN  ...          NaN          NaN          NaN
# 4             NaN        NaN  ...    19.143876    20.004849    26.266299
# ...           ...        ...  ...          ...          ...          ...
# 311824        NaN        NaN  ...          NaN          NaN          NaN
# 311825        NaN        NaN  ...  2070.000000  2310.000000  2360.000000
# 311826        NaN        NaN  ...          NaN          NaN          NaN
# 311827        NaN        NaN  ...          NaN          NaN          NaN
# 311828  78.124847  75.109494  ...    93.973094    87.032800    83.611816
#
#               v2015        v2016        v2017        v2018        v2019  \
# 0               NaN          NaN          NaN          NaN          NaN
# 1               NaN          NaN          NaN          NaN          NaN
# 2               NaN          NaN          NaN          NaN          NaN
# 3               NaN          NaN          NaN          NaN          NaN
# 4         31.860494    32.587242    34.540943    44.056308          NaN
# ...             ...          ...          ...          ...          ...
# 311824          NaN          NaN     0.036750          NaN          NaN
# 311825  2410.000000  2560.000000  2760.000000  2990.000000  2730.000000
# 311826          NaN          NaN     4.778166          NaN     4.674356
# 311827          NaN    14.400000          NaN          NaN          NaN
# 311828    89.515307    83.346653    79.358628    77.038048          NaN
#
#         v2020                     region
# 0         NaN  Latin America & Caribbean
# 1         NaN  Latin America & Caribbean
# 2         NaN  Latin America & Caribbean
# 3         NaN  Latin America & Caribbean
# 4         NaN  Latin America & Caribbean
# ...       ...                        ...
# 311824    NaN         Sub-Saharan Africa
# 311825    NaN         Sub-Saharan Africa
# 311826    NaN         Sub-Saharan Africa
# 311827    NaN         Sub-Saharan Africa
# 311828    NaN         Sub-Saharan Africa
#
# [311829 rows x 66 columns]

# %%
#Selecionando as colunas relevantes:
wdi_a = wdi[['countryname', 'countrycode', 'indicatorname', 'v2016']]
wdi_a
# Out:
#        countryname countrycode  \
# 0            Aruba         ABW
# 1            Aruba         ABW
# 2            Aruba         ABW
# 3            Aruba         ABW
# 4            Aruba         ABW
# ...            ...         ...
# 311824    Zimbabwe         ZWE
# 311825    Zimbabwe         ZWE
# 311826    Zimbabwe         ZWE
# 311827    Zimbabwe         ZWE
# 311828    Zimbabwe         ZWE
#
#                                             indicatorname        v2016
# 0       Logistics performance index: Competence and qu...          NaN
# 1       External debt stocks, private nonguaranteed (P...          NaN
# 2                      Time to resolve insolvency (years)          NaN
# 3       Level of water stress: freshwater withdrawal a...          NaN
# 4         Manufactures exports (% of merchandise exports)    32.587242
# ...                                                   ...          ...
# 311824  Educational attainment, Doctoral or equivalent...          NaN
# 311825      GNI per capita, PPP (current international $)  2560.000000
# 311826  Coverage of social insurance programs in 4th q...          NaN
# 311827  Informal payments to public officials (% of fi...    14.400000
# 311828  Households and NPISHs final consumption expend...    83.346653
#
# [311829 rows x 4 columns]

# %%
#Filtragem dos dados para obtenção de apenas a população e o PIB em 2016
wdi_a = wdi_a[(wdi_a['indicatorname'] == 'Population, total') | (wdi_a['indicatorname'] == 'GDP (current US$)')]
wdi_a

#Renomeando v2016:
wdi_a = wdi_a.rename(columns={'v2016':'2016'})
wdi_a
# Out:
#          countryname countrycode      indicatorname          2016
# 98             Aruba         ABW  GDP (current US$)  2.965922e+09
# 1207           Aruba         ABW  Population, total  1.048720e+05
# 1999     Afghanistan         AFG  Population, total  3.538313e+07
# 2432     Afghanistan         AFG  GDP (current US$)  1.936264e+10
# 3356          Angola         AGO  GDP (current US$)  1.011239e+11
# ...              ...         ...                ...           ...
# 308862  South Africa         ZAF  GDP (current US$)  2.963573e+11
# 309285        Zambia         ZMB  GDP (current US$)  2.095476e+10
# 310228        Zambia         ZMB  Population, total  1.636351e+07
# 311123      Zimbabwe         ZWE  GDP (current US$)  2.054868e+10
# 311380      Zimbabwe         ZWE  Population, total  1.403039e+07
#
# [434 rows x 4 columns]

# %%
#Pivotando a tabela para ter cada país em uma linha e as informações em colunas:
wdi_a = wdi_a.pivot(index='countryname', columns='indicatorname', values='2016').reset_index()
wdi_a
# Out:
# indicatorname            countryname  GDP (current US$)  Population, total
# 0                        Afghanistan       1.936264e+10         35383128.0
# 1                            Albania       1.186120e+10          2876101.0
# 2                            Algeria       1.600338e+11         40551404.0
# 3                     American Samoa       6.520000e+08            55741.0
# 4                            Andorra       2.896679e+09            77297.0
# ..                               ...                ...                ...
# 212            Virgin Islands (U.S.)       3.863000e+09           107510.0
# 213               West Bank and Gaza       1.342570e+10          4367088.0
# 214                      Yemen, Rep.       2.808468e+10         27168210.0
# 215                           Zambia       2.095476e+10         16363507.0
# 216                         Zimbabwe       2.054868e+10         14030390.0
#
# [217 rows x 3 columns]

# %%
#Renomeando as colunas:
wdi_a.columns = ['Country', 'GDP', 'Population']
wdi_a

#Conversão do PIB para bilhões de U$:
wdi_a['GDP'] = wdi_a['GDP'] / 10**9
wdi_a
# Out:
#                    Country         GDP  Population
# 0              Afghanistan   19.362642  35383128.0
# 1                  Albania   11.861201   2876101.0
# 2                  Algeria  160.033844  40551404.0
# 3           American Samoa    0.652000     55741.0
# 4                  Andorra    2.896679     77297.0
# ..                     ...         ...         ...
# 212  Virgin Islands (U.S.)    3.863000    107510.0
# 213     West Bank and Gaza   13.425700   4367088.0
# 214            Yemen, Rep.   28.084676  27168210.0
# 215                 Zambia   20.954762  16363507.0
# 216               Zimbabwe   20.548678  14030390.0
#
# [217 rows x 3 columns]

# %%
####################################Item b)#################################################################

# %%
##Importação da base de dados itpd:
itpd = pd.read_stata(r'C:/Users/pedro/Desktop/Base Python/itpd.dta')
itpd
# Out:
#          exporter_iso3 exporter_m49 importer_iso3 importer_m49  year  \
# 0                  ABW        Aruba           AGO       Angola  2000
# 1                  ABW        Aruba           AGO       Angola  2000
# 2                  ABW        Aruba           AGO       Angola  2000
# 3                  ABW        Aruba           AGO       Angola  2000
# 4                  ABW        Aruba           AGO       Angola  2000
# ...                ...          ...           ...          ...   ...
# 38518232           ZWE     Zimbabwe           ZWE     Zimbabwe  2016
# 38518233           ZWE     Zimbabwe           ZWE     Zimbabwe  2016
# 38518234           ZWE     Zimbabwe           ZWE     Zimbabwe  2016
# 38518235           ZWE     Zimbabwe           ZWE     Zimbabwe  2016
# 38518236           ZWE     Zimbabwe           ZWE     Zimbabwe  2016
#
#                                           industry_id   broad_sector  \
# 0                          Refined petroleum products  Manufacturing
# 1                           Structural metal products  Manufacturing
# 2                   Pumps compressors taps and valves  Manufacturing
# 3                     Other general purpose machinery  Manufacturing
# 4         TV and radio receivers and associated goods  Manufacturing
# ...                                               ...            ...
# 38518232                                         Corn    Agriculture
# 38518233                                Other cereals    Agriculture
# 38518234                                     Soybeans    Agriculture
# 38518235           Other oilseeds (excluding peanuts)    Agriculture
# 38518236         Pulses and legumes, dried, preserved    Agriculture
#
#                trade     flag_mirror                            flag_zero
# 0           0.000000  Reported value  u: Missing (unknown, assigned zero)
# 1           0.000000  Reported value  u: Missing (unknown, assigned zero)
# 2           0.000000  Reported value  u: Missing (unknown, assigned zero)
# 3           0.000000  Reported value  u: Missing (unknown, assigned zero)
# 4           0.000000  Reported value  u: Missing (unknown, assigned zero)
# ...              ...             ...                                  ...
# 38518232  331.533470  Reported value               p: Positive trade flow
# 38518233   29.803773  Reported value               p: Positive trade flow
# 38518234   38.413000  Reported value               p: Positive trade flow
# 38518235   27.450000  Reported value               p: Positive trade flow
# 38518236   14.574307  Reported value               p: Positive trade flow
#
# [38518237 rows x 10 columns]

# %%
#Exclusão do comércio doméstico:
itpd = itpd[itpd['exporter_iso3'] != itpd['importer_iso3']]
itpd
# Out:
#          exporter_iso3 exporter_m49 importer_iso3 importer_m49  year  \
# 0                  ABW        Aruba           AGO       Angola  2000
# 1                  ABW        Aruba           AGO       Angola  2000
# 2                  ABW        Aruba           AGO       Angola  2000
# 3                  ABW        Aruba           AGO       Angola  2000
# 4                  ABW        Aruba           AGO       Angola  2000
# ...                ...          ...           ...          ...   ...
# 38518190           ZWE     Zimbabwe           ZMB       Zambia  2016
# 38518191           ZWE     Zimbabwe           ZMB       Zambia  2016
# 38518192           ZWE     Zimbabwe           ZMB       Zambia  2016
# 38518193           ZWE     Zimbabwe           ZMB       Zambia  2016
# 38518194           ZWE     Zimbabwe           ZMB       Zambia  2016
#
#                                           industry_id   broad_sector  \
# 0                          Refined petroleum products  Manufacturing
# 1                           Structural metal products  Manufacturing
# 2                   Pumps compressors taps and valves  Manufacturing
# 3                     Other general purpose machinery  Manufacturing
# 4         TV and radio receivers and associated goods  Manufacturing
# ...                                               ...            ...
# 38518190               Jewellery and related articles  Manufacturing
# 38518191                          Musical instruments  Manufacturing
# 38518192                                 Sports goods  Manufacturing
# 38518193                               Games and toys  Manufacturing
# 38518194                   Other manufacturing n.e.c.  Manufacturing
#
#              trade     flag_mirror                            flag_zero
# 0         0.000000  Reported value  u: Missing (unknown, assigned zero)
# 1         0.000000  Reported value  u: Missing (unknown, assigned zero)
# 2         0.000000  Reported value  u: Missing (unknown, assigned zero)
# 3         0.000000  Reported value  u: Missing (unknown, assigned zero)
# 4         0.000000  Reported value  u: Missing (unknown, assigned zero)
# ...            ...             ...                                  ...
# 38518190  0.010282    Mirror value               p: Positive trade flow
# 38518191  0.000000  Reported value  u: Missing (unknown, assigned zero)
# 38518192  0.000115    Mirror value               p: Positive trade flow
# 38518193  0.002748    Mirror value               p: Positive trade flow
# 38518194  0.364066    Mirror value               p: Positive trade flow
#
# [38409788 rows x 10 columns]

# %%
#Selecionando apenas o ano de 2016:
itpd_2016 = itpd.loc[itpd['year'] == 2016]
itpd_2016
# Out:
#          exporter_iso3 exporter_m49 importer_iso3 importer_m49  year  \
# 144                ABW        Aruba           AGO       Angola  2016
# 145                ABW        Aruba           AGO       Angola  2016
# 146                ABW        Aruba           AGO       Angola  2016
# 147                ABW        Aruba           AGO       Angola  2016
# 148                ABW        Aruba           AGO       Angola  2016
# ...                ...          ...           ...          ...   ...
# 38518190           ZWE     Zimbabwe           ZMB       Zambia  2016
# 38518191           ZWE     Zimbabwe           ZMB       Zambia  2016
# 38518192           ZWE     Zimbabwe           ZMB       Zambia  2016
# 38518193           ZWE     Zimbabwe           ZMB       Zambia  2016
# 38518194           ZWE     Zimbabwe           ZMB       Zambia  2016
#
#                                           industry_id   broad_sector  \
# 144                        Refined petroleum products  Manufacturing
# 145                         Structural metal products  Manufacturing
# 146                 Pumps compressors taps and valves  Manufacturing
# 147                   Other general purpose machinery  Manufacturing
# 148       TV and radio receivers and associated goods  Manufacturing
# ...                                               ...            ...
# 38518190               Jewellery and related articles  Manufacturing
# 38518191                          Musical instruments  Manufacturing
# 38518192                                 Sports goods  Manufacturing
# 38518193                               Games and toys  Manufacturing
# 38518194                   Other manufacturing n.e.c.  Manufacturing
#
#              trade     flag_mirror                            flag_zero
# 144       0.000000  Reported value  u: Missing (unknown, assigned zero)
# 145       0.000000  Reported value  u: Missing (unknown, assigned zero)
# 146       0.000000  Reported value  u: Missing (unknown, assigned zero)
# 147       0.000000  Reported value  u: Missing (unknown, assigned zero)
# 148       0.000000  Reported value  u: Missing (unknown, assigned zero)
# ...            ...             ...                                  ...
# 38518190  0.010282    Mirror value               p: Positive trade flow
# 38518191  0.000000  Reported value  u: Missing (unknown, assigned zero)
# 38518192  0.000115    Mirror value               p: Positive trade flow
# 38518193  0.002748    Mirror value               p: Positive trade flow
# 38518194  0.364066    Mirror value               p: Positive trade flow
#
# [2258199 rows x 10 columns]

# %%
#Criando uma base para exportações:
itpd_e = itpd_2016[['exporter_m49','industry_id','broad_sector','trade']]
itpd_e.rename(columns = {'exporter_m49':'Country'}, inplace = True)
itpd_e
# Out:
# C:\Users\pedro\AppData\Local\Temp\ipykernel_23456\3031610951.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#            Country                                  industry_id  \
# 144          Aruba                   Refined petroleum products
# 145          Aruba                    Structural metal products
# 146          Aruba            Pumps compressors taps and valves
# 147          Aruba              Other general purpose machinery
# 148          Aruba  TV and radio receivers and associated goods
# ...            ...                                          ...
# 38518190  Zimbabwe               Jewellery and related articles
# 38518191  Zimbabwe                          Musical instruments
# 38518192  Zimbabwe                                 Sports goods
# 38518193  Zimbabwe                               Games and toys
# 38518194  Zimbabwe                   Other manufacturing n.e.c.
#
#            broad_sector     trade
# 144       Manufacturing  0.000000
# 145       Manufacturing  0.000000
# 146       Manufacturing  0.000000
# 147       Manufacturing  0.000000
# 148       Manufacturing  0.000000
# ...                 ...       ...
# 38518190  Manufacturing  0.010282
# 38518191  Manufacturing  0.000000
# 38518192  Manufacturing  0.000115
# 38518193  Manufacturing  0.002748
# 38518194  Manufacturing  0.364066
#
# [2258199 rows x 4 columns]

# %%
#Criando uma base para importações:
itpd_i = itpd_2016[['importer_m49','industry_id','broad_sector','trade']]
itpd_i.rename(columns = {'importer_m49':'Country'}, inplace = True)
itpd_i
# Out:
# C:\Users\pedro\AppData\Local\Temp\ipykernel_23456\1896646475.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#          Country                                  industry_id   broad_sector  \
# 144       Angola                   Refined petroleum products  Manufacturing
# 145       Angola                    Structural metal products  Manufacturing
# 146       Angola            Pumps compressors taps and valves  Manufacturing
# 147       Angola              Other general purpose machinery  Manufacturing
# 148       Angola  TV and radio receivers and associated goods  Manufacturing
# ...          ...                                          ...            ...
# 38518190  Zambia               Jewellery and related articles  Manufacturing
# 38518191  Zambia                          Musical instruments  Manufacturing
# 38518192  Zambia                                 Sports goods  Manufacturing
# 38518193  Zambia                               Games and toys  Manufacturing
# 38518194  Zambia                   Other manufacturing n.e.c.  Manufacturing
#
#              trade
# 144       0.000000
# 145       0.000000
# 146       0.000000
# 147       0.000000
# 148       0.000000
# ...            ...
# 38518190  0.010282
# 38518191  0.000000
# 38518192  0.000115
# 38518193  0.002748
# 38518194  0.364066
#
# [2258199 rows x 4 columns]

# %%
itpd_e = itpd_2016[['exporter_m49', 'broad_sector', 'trade']]
itpd_e = itpd_e.rename(columns={'exporter_m49': 'Country', 'trade': 'exports'})
itpd_e['Country'] = itpd_e['Country'].astype('category')
itpd_e['broad_sector'] = itpd['broad_sector'].astype('category')
#Convertendo para bilhões de U$:
itpd_e['exports'] = pd.to_numeric(itpd_e['exports'])/10**3
itpd_e = itpd_e.sort_values(by=['Country', 'broad_sector']).reset_index(drop=True)

itpd_i = itpd_2016[['importer_m49', 'broad_sector', 'trade']]
itpd_i = itpd_i.rename(columns={'importer_m49': 'Country2', 'trade': 'imports', 'broad_sector': 'broad_sector2'})
itpd_i['Country2'] = itpd_i['Country2'].astype('category')
itpd_i['broad_sector2'] = itpd_i['broad_sector2'].astype('category')
#Convertendo para bilhões de U$:
itpd_i['imports'] = pd.to_numeric(itpd_i['imports'])/10**3
itpd_i = itpd_i.sort_values(by=['Country2', 'broad_sector2']).reset_index(drop=True)

itpd_ie = pd.concat([itpd_e, itpd_i], axis=1)
itpd_ie.head(10)
# Out:
#        Country broad_sector   exports     Country2 broad_sector2   imports
# 0  Afghanistan  Agriculture  0.000022  Afghanistan   Agriculture  0.000000
# 1  Afghanistan  Agriculture  0.000000  Afghanistan   Agriculture  0.000000
# 2  Afghanistan  Agriculture  0.000004  Afghanistan   Agriculture  0.000000
# 3  Afghanistan  Agriculture  0.000534  Afghanistan   Agriculture  0.000000
# 4  Afghanistan  Agriculture  0.001114  Afghanistan   Agriculture  0.000112
# 5  Afghanistan  Agriculture  0.000017  Afghanistan   Agriculture  0.000085
# 6  Afghanistan  Agriculture  0.000242  Afghanistan   Agriculture  0.000000
# 7  Afghanistan  Agriculture  0.002156  Afghanistan   Agriculture  0.009479
# 8  Afghanistan  Agriculture  0.001016  Afghanistan   Agriculture  0.012054
# 9  Afghanistan  Agriculture  0.000104  Afghanistan   Agriculture  0.000025

# %%
itpd_ie = itpd_ie[['Country', 'broad_sector', 'exports', 'imports']]
itpd_ie['trade_balance'] = itpd_ie['exports'] - itpd_ie['imports']
itpd_ie.head(10)
# Out:
#        Country broad_sector   exports   imports  trade_balance
# 0  Afghanistan  Agriculture  0.000022  0.000000       0.000022
# 1  Afghanistan  Agriculture  0.000000  0.000000       0.000000
# 2  Afghanistan  Agriculture  0.000004  0.000000       0.000004
# 3  Afghanistan  Agriculture  0.000534  0.000000       0.000534
# 4  Afghanistan  Agriculture  0.001114  0.000112       0.001002
# 5  Afghanistan  Agriculture  0.000017  0.000085      -0.000068
# 6  Afghanistan  Agriculture  0.000242  0.000000       0.000242
# 7  Afghanistan  Agriculture  0.002156  0.009479      -0.007323
# 8  Afghanistan  Agriculture  0.001016  0.012054      -0.011038
# 9  Afghanistan  Agriculture  0.000104  0.000025       0.000079

# %%
# Criando importações e exportações totais por país e por setor

#Agregando variáveis numéricas:
itpd_ie_sector = itpd_ie.groupby(['Country', 'broad_sector']).agg(exports=('exports', 'sum'), imports=('imports', 'sum'), trade_balance=('trade_balance', 'sum')).reset_index()

itpd_ie_sector.columns = ['Country', 'broad_sector', 'exports', 'imports', 'trade_balance']

itpd_ie_sector = pd.DataFrame(itpd_ie_sector)
itpd_ie_sector['total_commerce'] = itpd_ie_sector['exports'] + itpd_ie_sector['imports']

itpd_ie_sector.head(10)
# Out:
#        Country     broad_sector       exports   imports  trade_balance  \
# 0  Afghanistan      Agriculture  4.892683e-01  0.472355   1.691287e-02
# 1  Afghanistan  Mining & Energy  9.757177e-02  0.006542   9.102996e-02
# 2  Afghanistan    Manufacturing  3.192499e-01  4.962128  -4.642878e+00
# 3  Afghanistan         Services  1.300000e-03  0.020979  -1.967901e-02
# 4      Albania      Agriculture  1.080260e-01  0.858472  -7.504462e-01
# 5      Albania  Mining & Energy  5.116979e-01  0.020946   4.907519e-01
# 6      Albania    Manufacturing  1.533651e+00  3.469467  -1.935817e+00
# 7      Albania         Services  1.000000e-04  0.004204  -4.103709e-03
# 8   Antarctica      Agriculture  0.000000e+00  0.000000   0.000000e+00
# 9   Antarctica  Mining & Energy  2.490000e-07  0.000000   2.490000e-07
#
#    total_commerce
# 0    9.616237e-01
# 1    1.041136e-01
# 2    5.281378e+00
# 3    2.227901e-02
# 4    9.664982e-01
# 5    5.326439e-01
# 6    5.003118e+00
# 7    4.303709e-03
# 8    0.000000e+00
# 9    2.490000e-07

# %%
# Criando importações e exportações totais por país

itpd_ie_total = itpd_ie.groupby(['Country']).agg(exports=('exports', 'sum'), imports=('imports', 'sum'), trade_balance=('trade_balance', 'sum')).reset_index()

itpd_ie_total.columns = ['Country', 'exports', 'imports', 'trade_balance']

itpd_ie_total = pd.DataFrame(itpd_ie_total)
itpd_ie_total['total_commerce'] = itpd_ie_total['exports'] + itpd_ie_total['imports']

itpd_ie_total.head(10)
# Out:
#                Country    exports    imports  trade_balance  total_commerce
# 0          Afghanistan   0.907390   5.462004      -4.554614        6.369394
# 1              Albania   2.153475   4.353089      -2.199614        6.506564
# 2           Antarctica   0.008771   0.118942      -0.110170        0.127713
# 3              Algeria  30.914690  29.175478       1.739213       60.090168
# 4       American Samoa   0.040456   9.925414      -9.884958        9.965870
# 5              Andorra   0.096728   9.233462      -9.136734        9.330190
# 6               Angola  27.971460   1.264365      26.707096       29.235825
# 7  Antigua and Barbuda   0.267803   4.210697      -3.942894        4.478500
# 8           Azerbaijan  12.563601   5.289180       7.274422       17.852781
# 9            Argentina  64.504365   6.228955      58.275410       70.733320

# %%
# Combinando informações de comércio por setor e país e do Banco Mundial:
final_database_sector = pd.merge(wdi_a, itpd_ie_sector, on = 'Country', how = 'right')
final_database_sector.head()
# Out:
#        Country        GDP  Population     broad_sector   exports   imports  \
# 0  Afghanistan  19.362642  35383128.0      Agriculture  0.489268  0.472355
# 1  Afghanistan  19.362642  35383128.0  Mining & Energy  0.097572  0.006542
# 2  Afghanistan  19.362642  35383128.0    Manufacturing  0.319250  4.962128
# 3  Afghanistan  19.362642  35383128.0         Services  0.001300  0.020979
# 4      Albania  11.861201   2876101.0      Agriculture  0.108026  0.858472
#
#    trade_balance  total_commerce
# 0       0.016913        0.961624
# 1       0.091030        0.104114
# 2      -4.642878        5.281378
# 3      -0.019679        0.022279
# 4      -0.750446        0.966498

# %%
# Combinando informações de comércio por país e do Banco Mundial:
final_database_total = pd.merge(wdi_a, itpd_ie_total, on = 'Country', how = 'right')
final_database_total
# Out:
#                        Country         GDP  Population    exports    imports  \
# 0                  Afghanistan   19.362642  35383128.0   0.907390   5.462004
# 1                      Albania   11.861201   2876101.0   2.153475   4.353089
# 2                   Antarctica         NaN         NaN   0.008771   0.118942
# 3                      Algeria  160.033844  40551404.0  30.914690  29.175478
# 4               American Samoa    0.652000     55741.0   0.040456   9.925414
# ..                         ...         ...         ...        ...        ...
# 236  Wallis and Futuna Islands         NaN         NaN   0.000386   0.344644
# 237                      Samoa    0.799376    194535.0   0.183128   1.781010
# 238                      Yemen         NaN         NaN   0.859306   1.589627
# 239      Serbia and Montenegro         NaN         NaN   0.000000   0.000000
# 240                     Zambia   20.954762  16363507.0   5.481148   3.020655
#
#      trade_balance  total_commerce
# 0        -4.554614        6.369394
# 1        -2.199614        6.506564
# 2        -0.110170        0.127713
# 3         1.739213       60.090168
# 4        -9.884958        9.965870
# ..             ...             ...
# 236      -0.344258        0.345030
# 237      -1.597882        1.964138
# 238      -0.730321        2.448933
# 239       0.000000        0.000000
# 240       2.460492        8.501803
#
# [241 rows x 7 columns]

# %%
final_database_total["ln(exports)"] = np.log(final_database_total["exports"])
final_database_total["ln(imports)"] = np.log(final_database_total["imports"])
final_database_total
# Out:
# C:\Users\pedro\anaconda3\lib\site-packages\pandas\core\arraylike.py:397: RuntimeWarning: divide by zero encountered in log
# C:\Users\pedro\anaconda3\lib\site-packages\pandas\core\arraylike.py:397: RuntimeWarning: divide by zero encountered in log
#                        Country         GDP  Population    exports    imports  \
# 0                  Afghanistan   19.362642  35383128.0   0.907390   5.462004
# 1                      Albania   11.861201   2876101.0   2.153475   4.353089
# 2                   Antarctica         NaN         NaN   0.008771   0.118942
# 3                      Algeria  160.033844  40551404.0  30.914690  29.175478
# 4               American Samoa    0.652000     55741.0   0.040456   9.925414
# ..                         ...         ...         ...        ...        ...
# 236  Wallis and Futuna Islands         NaN         NaN   0.000386   0.344644
# 237                      Samoa    0.799376    194535.0   0.183128   1.781010
# 238                      Yemen         NaN         NaN   0.859306   1.589627
# 239      Serbia and Montenegro         NaN         NaN   0.000000   0.000000
# 240                     Zambia   20.954762  16363507.0   5.481148   3.020655
#
#      trade_balance  total_commerce  ln(exports)  ln(imports)
# 0        -4.554614        6.369394    -0.097183     1.697816
# 1        -2.199614        6.506564     0.767083     1.470886
# 2        -0.110170        0.127713    -4.736266    -2.129122
# 3         1.739213       60.090168     3.431231     3.373329
# 4        -9.884958        9.965870    -3.207545     2.295099
# ..             ...             ...          ...          ...
# 236      -0.344258        0.345030    -7.860593    -1.065243
# 237      -1.597882        1.964138    -1.697569     0.577181
# 238      -0.730321        2.448933    -0.151630     0.463499
# 239       0.000000        0.000000         -inf         -inf
# 240       2.460492        8.501803     1.701315     1.105474
#
# [241 rows x 9 columns]

# %%
#####################################2.2####################################################################

# %%
#Item a)
ggplot(final_database_total, aes(x="ln(exports)", y="ln(imports)", size="GDP")) + \
    geom_point(alpha=0.8, fill="darkblue") + \
    labs(x="Exportações (bilhões de U$)", y="Importações (bilhões de U$)", \
         title="Exportações x Importações ponderada pelo PIB") + \
    geom_smooth(method="lm", color="red", se=False, show_legend=False) + \
    theme_classic()
# Out:
# C:\Users\pedro\anaconda3\lib\site-packages\plotnine\layer.py:411: PlotnineWarning: geom_point : Removed 64 rows containing missing values.
# <ggplot: (166448432351)>

# %%
##########################################Item b)###########################################################
final_database_total["total_commerce/GDP"] = final_database_total["total_commerce"]/final_database_total["GDP"]
final_database_total

final_database_total["ln(GDP)"] = np.log(final_database_total["GDP"])
final_database_total
# Out:
#                        Country         GDP  Population    exports    imports  \
# 0                  Afghanistan   19.362642  35383128.0   0.907390   5.462004
# 1                      Albania   11.861201   2876101.0   2.153475   4.353089
# 2                   Antarctica         NaN         NaN   0.008771   0.118942
# 3                      Algeria  160.033844  40551404.0  30.914690  29.175478
# 4               American Samoa    0.652000     55741.0   0.040456   9.925414
# ..                         ...         ...         ...        ...        ...
# 236  Wallis and Futuna Islands         NaN         NaN   0.000386   0.344644
# 237                      Samoa    0.799376    194535.0   0.183128   1.781010
# 238                      Yemen         NaN         NaN   0.859306   1.589627
# 239      Serbia and Montenegro         NaN         NaN   0.000000   0.000000
# 240                     Zambia   20.954762  16363507.0   5.481148   3.020655
#
#      trade_balance  total_commerce  ln(exports)  ln(imports)  \
# 0        -4.554614        6.369394    -0.097183     1.697816
# 1        -2.199614        6.506564     0.767083     1.470886
# 2        -0.110170        0.127713    -4.736266    -2.129122
# 3         1.739213       60.090168     3.431231     3.373329
# 4        -9.884958        9.965870    -3.207545     2.295099
# ..             ...             ...          ...          ...
# 236      -0.344258        0.345030    -7.860593    -1.065243
# 237      -1.597882        1.964138    -1.697569     0.577181
# 238      -0.730321        2.448933    -0.151630     0.463499
# 239       0.000000        0.000000         -inf         -inf
# 240       2.460492        8.501803     1.701315     1.105474
#
#      total_commerce/GDP   ln(GDP)
# 0              0.328953  2.963346
# 1              0.548559  2.473273
# 2                   NaN       NaN
# 3              0.375484  5.075385
# 4             15.285076 -0.427711
# ..                  ...       ...
# 236                 NaN       NaN
# 237            2.457088 -0.223923
# 238                 NaN       NaN
# 239                 NaN       NaN
# 240            0.405722  3.042366
#
# [241 rows x 11 columns]

# %%
#Gráfico com outliers:
(ggplot(final_database_total, aes(x = "ln(GDP)", y = "total_commerce/GDP")) + \
     geom_point(alpha = 0.8, color = "darkblue") + \
     labs(x = "Log do PIB (bilhões de U$)", y = "Comércio total/PIB (bilhões de U$)",
         title = "Comércio total como relação do PIB x log PIB") + \
     geom_smooth(method="lm", color="red", se=False, show_legend=False) + \
     theme_classic())
# Out:
# C:\Users\pedro\anaconda3\lib\site-packages\plotnine\layer.py:411: PlotnineWarning: geom_point : Removed 64 rows containing missing values.
# <ggplot: (166461177230)>

# %%
#Gráfico sem outliers:
(ggplot(final_database_total, aes(x = "ln(GDP)", y = "total_commerce/GDP")) + \
     geom_point(alpha = 0.8, color = "darkblue") + \
     labs(x = "Log do PIB (bilhões de U$)", y = "Comércio total/PIB (bilhões de U$)",
         title = "Comércio total como relação do PIB x log PIB") + \
     geom_smooth(method="lm", color="red", se=False, show_legend=False) + \
     ylim(0,20) + \
     theme_classic())
# Out:
# C:\Users\pedro\anaconda3\lib\site-packages\plotnine\layer.py:411: PlotnineWarning: geom_point : Removed 73 rows containing missing values.
# C:\Users\pedro\anaconda3\lib\site-packages\plotnine\layer.py:411: PlotnineWarning: geom_smooth : Removed 15 rows containing missing values.
# <ggplot: (166461235896)>

# %%
######################################Item 2.3#############################################################
#Item a)
#Retirando os dados desnecessários ao que pede o item:
final_database_sector = final_database_sector.drop(columns=["trade_balance", "total_commerce"])
final_database_sector["exports/pop"] = final_database_sector["exports"]/final_database_sector["Population"]
final_database_sector["imports/pop"] = final_database_sector["imports"]/final_database_sector["Population"]
final_database_sector.head(10)
# Out:
#        Country        GDP  Population     broad_sector       exports  \
# 0  Afghanistan  19.362642  35383128.0      Agriculture  4.892683e-01
# 1  Afghanistan  19.362642  35383128.0  Mining & Energy  9.757177e-02
# 2  Afghanistan  19.362642  35383128.0    Manufacturing  3.192499e-01
# 3  Afghanistan  19.362642  35383128.0         Services  1.300000e-03
# 4      Albania  11.861201   2876101.0      Agriculture  1.080260e-01
# 5      Albania  11.861201   2876101.0  Mining & Energy  5.116979e-01
# 6      Albania  11.861201   2876101.0    Manufacturing  1.533651e+00
# 7      Albania  11.861201   2876101.0         Services  1.000000e-04
# 8   Antarctica        NaN         NaN      Agriculture  0.000000e+00
# 9   Antarctica        NaN         NaN  Mining & Energy  2.490000e-07
#
#     imports   exports/pop   imports/pop
# 0  0.472355  1.382773e-08  1.334974e-08
# 1  0.006542  2.757579e-09  1.848852e-10
# 2  4.962128  9.022659e-09  1.402399e-07
# 3  0.020979  3.674068e-11  5.929099e-10
# 4  0.858472  3.755988e-08  2.984847e-07
# 5  0.020946  1.779137e-07  7.282776e-09
# 6  3.469467  5.332395e-07  1.206309e-06
# 7  0.004204  3.476929e-11  1.461600e-09
# 8  0.000000           NaN           NaN
# 9  0.000000           NaN           NaN

# %%
final_a_exports_pc= final_database_sector.pivot(index='Country', columns='broad_sector', values='exports/pop').reset_index()
final_a_exports_pc.head(50)
# Out:
# broad_sector                           Country   Agriculture  Mining & Energy  \
# 0                                  Afghanistan  1.382773e-08     2.757579e-09
# 1                                      Albania  3.755988e-08     1.779137e-07
# 2                                      Algeria  1.454845e-09     5.128387e-07
# 3                               American Samoa  2.951203e-09     9.036130e-08
# 4                                      Andorra  1.125529e-09     3.687206e-10
# 5                                       Angola  4.281878e-11     9.427116e-07
# 6                                     Anguilla           NaN              NaN
# 7                                   Antarctica           NaN              NaN
# 8                          Antigua and Barbuda  3.935384e-08     1.950765e-11
# 9                                    Argentina  3.559084e-07     4.461524e-08
# 10                                     Armenia  1.960700e-08     2.888693e-07
# 11                                       Aruba  3.088527e-08     1.142669e-09
# 12                                   Australia  6.278531e-07     4.320752e-06
# 13                                     Austria  1.940654e-07     1.949988e-07
# 14                                  Azerbaijan  3.944116e-08     1.135804e-06
# 15                                Bahamas, The  6.530293e-09     4.055567e-07
# 16                                     Bahrain  1.140628e-08     1.547822e-06
# 17                                  Bangladesh  2.332117e-09     6.861480e-11
# 18                                    Barbados  6.588651e-09     3.592553e-08
# 19                                     Belarus  3.526892e-08     6.740231e-08
# 20                                     Belgium  6.324726e-07     1.674076e-06
# 21                                      Belize  1.815406e-07     3.072837e-08
# 22                                       Benin  3.984836e-08     3.014820e-10
# 23                                     Bermuda  1.580072e-09     1.483264e-07
# 24                                      Bhutan  1.047904e-09     9.114236e-10
# 25                                     Bolivia  4.269570e-08     3.035449e-07
# 26            Bonaire, Sint Eustatius and Saba           NaN              NaN
# 27                      Bosnia and Herzegovina  2.798539e-08     8.986758e-08
# 28                                    Botswana  4.884898e-09     3.071487e-06
# 29                               Bouvet Island           NaN              NaN
# 30                                      Brazil  1.771807e-07     1.844335e-07
# 31                   British Indian Ocean Ter.           NaN              NaN
# 32                      British Virgin Islands  2.306251e-08     1.453074e-09
# 33                                      Brunei           NaN              NaN
# 34                                    Bulgaria  3.239039e-07     1.655444e-07
# 35                                Burkina Faso  4.107900e-08     5.079597e-09
# 36                                     Burundi  7.783299e-09     1.741672e-10
# 37                                    Cambodia  3.144102e-08     3.875226e-09
# 38                                    Cameroon  4.789549e-08     4.956916e-08
# 39                                      Canada  5.933731e-07     1.698977e-06
# 40                                  Cape Verde           NaN              NaN
# 41                              Cayman Islands  1.443207e-08     3.575573e-10
# 42                    Central African Republic  9.010329e-09     2.536416e-10
# 43                                        Chad  3.735974e-09     9.554555e-08
# 44                                       Chile  4.726555e-07     8.077881e-07
# 45                                       China  1.466312e-08     5.249644e-09
# 46                            Christmas Island           NaN              NaN
# 47                     Cocos (Keeling) Islands           NaN              NaN
# 48                                    Colombia  1.133073e-07     3.811224e-07
# 49                                     Comoros  6.516405e-08     0.000000e+00
#
# broad_sector  Manufacturing      Services
# 0              9.022659e-09  3.674068e-11
# 1              5.332395e-07  3.476929e-11
# 2              2.472852e-07  7.792579e-10
# 3              6.324697e-07  0.000000e+00
# 4              1.242122e-06  7.762268e-09
# 5              2.687985e-08  1.664212e-10
# 6                       NaN           NaN
# 7                       NaN           NaN
# 8              2.793712e-06  0.000000e+00
# 9              1.001994e-06  7.726686e-08
# 10             3.910858e-07  4.996346e-08
# 11             1.756479e-06  9.535434e-10
# 12             3.217387e-06  8.288814e-07
# 13             1.461246e-05  6.610069e-06
# 14             1.013838e-07  1.091433e-08
# 15             3.561719e-06  2.910584e-08
# 16             5.975596e-06  4.285341e-08
# 17             2.314621e-07  1.582571e-11
# 18             1.542933e-06  2.134390e-08
# 19             1.925372e-06  0.000000e+00
# 20             2.383903e-05  8.854531e-06
# 21             9.183617e-07  3.064604e-07
# 22             5.891047e-08  0.000000e+00
# 23             6.561691e-06  3.749373e-04
# 24             1.864709e-07  0.000000e+00
# 25             2.578486e-07  9.064693e-12
# 26                      NaN           NaN
# 27             1.399135e-06  1.476552e-10
# 28             5.420257e-07  0.000000e+00
# 29                      NaN           NaN
# 30             6.081129e-07  8.038374e-08
# 31                      NaN           NaN
# 32             2.170348e-05  3.866462e-06
# 33                      NaN           NaN
# 34             2.989406e-06  1.020358e-06
# 35             8.245647e-08  0.000000e+00
# 36             1.089180e-08  0.000000e+00
# 37             9.464559e-07  6.342645e-11
# 38             5.109345e-08  0.000000e+00
# 39             7.812000e-06  1.640523e-06
# 40                      NaN           NaN
# 41             3.589804e-05  7.729067e-06
# 42             5.236107e-09  0.000000e+00
# 43             1.317994e-08  6.867346e-11
# 44             2.122852e-06  2.507734e-07
# 45             1.640766e-06  9.950255e-08
# 46                      NaN           NaN
# 47                      NaN           NaN
# 48             3.054313e-07  3.765721e-08
# 49             2.446683e-08  0.000000e+00

# %%
final_a_imports_pc= final_database_sector.pivot(index='Country', columns='broad_sector', values='imports/pop').reset_index()

# %%
#Item b)
import geopandas as gpd

#leitura dos dados geográficos de cada país
map_data = gpd.read_file(r'C:/Users/pedro/Desktop/com_int_dados_aps1/ne_110m_admin_0_countries/ne_110m_admin_0_countries.shp')
map_data

#Renomeando "SOVEREIGNT" para "Country"
map_data = map_data.rename(columns = {"SOVEREIGNT" : "Country"})

# %%
#Base agregada com os dados geográficos e de exportações per capita
final_a_exports_pc_map = pd.merge(map_data, final_a_exports_pc, on='Country')
final_a_exports_pc_map.head(10)

#Base agregada com os dados geográficos e de importações per capita
final_a_imports_pc_map = pd.merge(map_data, final_a_imports_pc, on='Country')
final_a_imports_pc_map.head(10)
# Out:
#         featurecla  scalerank  LABELRANK           Country SOV_A3  ADM0_DIF  \
# 0  Admin-0 country          1          6              Fiji    FJI         0
# 1  Admin-0 country          1          7    Western Sahara    SAH         0
# 2  Admin-0 country          1          2            Canada    CAN         0
# 3  Admin-0 country          1          3        Kazakhstan    KA1         1
# 4  Admin-0 country          1          3        Uzbekistan    UZB         0
# 5  Admin-0 country          1          2  Papua New Guinea    PNG         0
# 6  Admin-0 country          1          2         Indonesia    IDN         0
# 7  Admin-0 country          1          2         Argentina    ARG         0
# 8  Admin-0 country          1          2             Chile    CHL         0
# 9  Admin-0 country          1          6           Somalia    SOM         0
#
#    LEVEL               TYPE TLC             ADMIN  ... FCLASS_IT  \
# 0      2  Sovereign country   1              Fiji  ...       NaN
# 1      2      Indeterminate   1    Western Sahara  ...       NaN
# 2      2  Sovereign country   1            Canada  ...       NaN
# 3      1        Sovereignty   1        Kazakhstan  ...       NaN
# 4      2  Sovereign country   1        Uzbekistan  ...       NaN
# 5      2  Sovereign country   1  Papua New Guinea  ...       NaN
# 6      2  Sovereign country   1         Indonesia  ...       NaN
# 7      2  Sovereign country   1         Argentina  ...       NaN
# 8      2  Sovereign country   1             Chile  ...       NaN
# 9      2  Sovereign country   1           Somalia  ...       NaN
#
#       FCLASS_NL FCLASS_SE FCLASS_BD  FCLASS_UA  \
# 0           NaN       NaN       NaN        NaN
# 1  Unrecognized       NaN       NaN        NaN
# 2           NaN       NaN       NaN        NaN
# 3           NaN       NaN       NaN        NaN
# 4           NaN       NaN       NaN        NaN
# 5           NaN       NaN       NaN        NaN
# 6           NaN       NaN       NaN        NaN
# 7           NaN       NaN       NaN        NaN
# 8           NaN       NaN       NaN        NaN
# 9           NaN       NaN       NaN        NaN
#
#                                             geometry   Agriculture  \
# 0  MULTIPOLYGON (((180.00000 -16.06713, 180.00000...  1.112722e-08
# 1  POLYGON ((-8.66559 27.65643, -8.66512 27.58948...           NaN
# 2  MULTIPOLYGON (((-122.84000 49.00000, -122.9742...  1.505709e-07
# 3  POLYGON ((87.35997 49.21498, 86.59878 48.54918...  1.110084e-07
# 4  POLYGON ((55.96819 41.30864, 55.92892 44.99586...  5.905817e-09
# 5  MULTIPOLYGON (((141.00021 -2.60015, 142.73525 ...  7.929934e-09
# 6  MULTIPOLYGON (((141.00021 -2.60015, 141.01706 ...  2.260245e-09
# 7  MULTIPOLYGON (((-68.63401 -52.63637, -68.25000...  3.936866e-09
# 8  MULTIPOLYGON (((-68.63401 -52.63637, -68.63335...  1.715763e-09
# 9  POLYGON ((41.58513 -1.68325, 40.99300 -0.85829...  2.429005e-08
#
#    Mining & Energy Manufacturing      Services
# 0     0.000000e+00  8.380298e-06  1.570114e-08
# 1              NaN           NaN           NaN
# 2     1.148141e-08  2.773346e-06  3.874073e-07
# 3     9.895265e-09  9.999286e-07  2.614525e-09
# 4     2.913137e-11  6.008493e-08  7.003033e-11
# 5     1.332256e-11  1.125945e-06  4.315510e-09
# 6     2.477425e-10  1.451232e-06  1.144607e-08
# 7     4.974426e-10  1.377282e-07  7.349834e-10
# 8     5.055520e-11  1.030202e-06  1.827060e-08
# 9     5.979309e-09  9.615580e-07  0.000000e+00
#
# [10 rows x 173 columns]

# %%
# !pip install mapclassify

# %%
from mpl_toolkits.axes_grid1 import make_axes_locatable 
world= final_a_imports_pc_map[(final_a_imports_pc_map.Services>0) & (final_a_imports_pc_map.Country!="Antarctica") & (final_a_imports_pc_map['Mining & Energy']>0) & (final_a_imports_pc_map['Manufacturing']>0) & (final_a_imports_pc_map['Agriculture']>0)]

# %%
import mapclassify
from mpl_toolkits.axes_grid1 import make_axes_locatable

q10 = mapclassify.Quantiles(world.Services, k=5)

fig, ax = plt.subplots(figsize=(16, 9))
world.assign(cl=q10.yb).plot(
    column="Services",
    categorical=True,
    k=2,
    cmap="OrRd",
    linewidth=1,
    edgecolor="white",
    ax=ax
)
ax.set_axis_off()

# Add a legend using the mpl_toolkits.axes_grid1 module
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="5%", pad=0.1)
sm = plt.cm.ScalarMappable(cmap="OrRd", norm=plt.Normalize(vmin=q10.yb.min(), vmax=q10.yb.max()))
sm._A = []  # creates an empty array to avoid an error
cbar = plt.colorbar(sm, cax=cax)
cbar.ax.set_ylabel("Services", fontsize=14)

# Add a title
plt.title("Import Per Capta By Services Sector", fontsize=13)

# Show the plot
plt.show()

# %%
q10 = mapclassify.Quantiles(world.Agriculture, k=5)

fig, ax = plt.subplots(figsize=(16, 9))
world.assign(cl=q10.yb).plot(
    column="Agriculture",
    categorical=True,
    k=2,
    cmap="OrRd",
    linewidth=1,
    edgecolor="white",
    ax=ax
)
ax.set_axis_off()

# Add a legend using the mpl_toolkits.axes_grid1 module
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="5%", pad=0.1)
sm = plt.cm.ScalarMappable(cmap="OrRd", norm=plt.Normalize(vmin=q10.yb.min(), vmax=q10.yb.max()))
sm._A = []  # creates an empty array to avoid an error
cbar = plt.colorbar(sm, cax=cax)
cbar.ax.set_ylabel("Agriculture", fontsize=14)

# Add a title
plt.title("Import Per Capta By Agriculture Sector", fontsize=13)

# Show the plot
plt.show()

# %%
q10 = mapclassify.Quantiles(world['Mining & Energy'], k=5)

fig, ax = plt.subplots(figsize=(16, 9))
world.assign(cl=q10.yb).plot(
    column="Mining & Energy",
    categorical=True,
    k=2,
    cmap="OrRd",
    linewidth=1,
    edgecolor="white",
    ax=ax
)
ax.set_axis_off()

# Add a legend using the mpl_toolkits.axes_grid1 module
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="5%", pad=0.1)
sm = plt.cm.ScalarMappable(cmap="OrRd", norm=plt.Normalize(vmin=q10.yb.min(), vmax=q10.yb.max()))
sm._A = []  # creates an empty array to avoid an error
cbar = plt.colorbar(sm, cax=cax)
cbar.ax.set_ylabel("Mining & Energy", fontsize=14)

# Add a title
plt.title("Import Per Capta By Mining & Energy Sector", fontsize=13)

# Show the plot
plt.show()

# %%
q10 = mapclassify.Quantiles(world['Manufacturing'], k=5)

fig, ax = plt.subplots(figsize=(16, 9))
world.assign(cl=q10.yb).plot(
    column="Manufacturing",
    categorical=True,
    k=2,
    cmap="OrRd",
    linewidth=1,
    edgecolor="white",
    ax=ax
)
ax.set_axis_off()

# Add a legend using the mpl_toolkits.axes_grid1 module
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="5%", pad=0.1)
sm = plt.cm.ScalarMappable(cmap="OrRd", norm=plt.Normalize(vmin=q10.yb.min(), vmax=q10.yb.max()))
sm._A = []  # creates an empty array to avoid an error
cbar = plt.colorbar(sm, cax=cax)
cbar.ax.set_ylabel("Manufacturing", fontsize=14)

# Add a title
plt.title("Import Per Capta By Manufacturing Sector", fontsize=13)

# Show the plot
plt.show()

# %%
world_ex= final_a_exports_pc_map[(final_a_exports_pc_map.Services>0) & (final_a_exports_pc_map.Country!="Antarctica") & (final_a_exports_pc_map['Mining & Energy']>0) & (final_a_exports_pc_map['Manufacturing']>0) & (final_a_exports_pc_map['Agriculture']>0)]

# %%
q10 = mapclassify.Quantiles(world_ex['Mining & Energy'], k=5)

fig, ax = plt.subplots(figsize=(16, 9))
world_ex.assign(cl=q10.yb).plot(
    column="Mining & Energy",
    categorical=True,
    k=2,
    cmap="OrRd",
    linewidth=1,
    edgecolor="white",
    ax=ax
)
ax.set_axis_off()

# Add a legend using the mpl_toolkits.axes_grid1 module
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="5%", pad=0.1)
sm = plt.cm.ScalarMappable(cmap="OrRd", norm=plt.Normalize(vmin=q10.yb.min(), vmax=q10.yb.max()))
sm._A = []  # creates an empty array to avoid an error
cbar = plt.colorbar(sm, cax=cax)
cbar.ax.set_ylabel("Mining & Energy", fontsize=14)

# Add a title
plt.title("Exports Per Capta By Mining & Energy Sector", fontsize=13)

# Show the plot
plt.show()

# %%
q10 = mapclassify.Quantiles(world_ex.Manufacturing, k=5)

fig, ax = plt.subplots(figsize=(16, 9))
world_ex.assign(cl=q10.yb).plot(
    column="Manufacturing",
    categorical=True,
    k=2,
    cmap="OrRd",
    linewidth=1,
    edgecolor="white",
    ax=ax
)
ax.set_axis_off()

# Add a legend using the mpl_toolkits.axes_grid1 module
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="5%", pad=0.1)
sm = plt.cm.ScalarMappable(cmap="OrRd", norm=plt.Normalize(vmin=q10.yb.min(), vmax=q10.yb.max()))
sm._A = []  # creates an empty array to avoid an error
cbar = plt.colorbar(sm, cax=cax)
cbar.ax.set_ylabel("Manufacturing", fontsize=14)

# Add a title
plt.title("Exports Per Capta By Manufacturing Sector", fontsize=13)

# Show the plot
plt.show()

# %%
q10 = mapclassify.Quantiles(world_ex.Agriculture, k=5)

fig, ax = plt.subplots(figsize=(16, 9))
world_ex.assign(cl=q10.yb).plot(
    column="Agriculture",
    categorical=True,
    k=2,
    cmap="OrRd",
    linewidth=1,
    edgecolor="white",
    ax=ax
)
ax.set_axis_off()

# Add a legend using the mpl_toolkits.axes_grid1 module
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="5%", pad=0.1)
sm = plt.cm.ScalarMappable(cmap="OrRd", norm=plt.Normalize(vmin=q10.yb.min(), vmax=q10.yb.max()))
sm._A = []  # creates an empty array to avoid an error
cbar = plt.colorbar(sm, cax=cax)
cbar.ax.set_ylabel("Agriculture", fontsize=14)

# Add a title
plt.title("Exports Per Capta By Agriculture Sector", fontsize=13)

# Show the plot
plt.show()

# %%
final_database_sector
# Out:
#                    Country        GDP  Population     broad_sector   exports  \
# 0              Afghanistan  19.362642  35383128.0      Agriculture  0.489268
# 1              Afghanistan  19.362642  35383128.0  Mining & Energy  0.097572
# 2              Afghanistan  19.362642  35383128.0    Manufacturing  0.319250
# 3              Afghanistan  19.362642  35383128.0         Services  0.001300
# 4                  Albania  11.861201   2876101.0      Agriculture  0.108026
# ..                     ...        ...         ...              ...       ...
# 959  Serbia and Montenegro        NaN         NaN         Services  0.000000
# 960                 Zambia  20.954762  16363507.0      Agriculture  0.517926
# 961                 Zambia  20.954762  16363507.0  Mining & Energy  0.143901
# 962                 Zambia  20.954762  16363507.0    Manufacturing  4.819320
# 963                 Zambia  20.954762  16363507.0         Services  0.000000
#
#       imports   exports/pop   imports/pop
# 0    0.472355  1.382773e-08  1.334974e-08
# 1    0.006542  2.757579e-09  1.848852e-10
# 2    4.962128  9.022659e-09  1.402399e-07
# 3    0.020979  3.674068e-11  5.929099e-10
# 4    0.858472  3.755988e-08  2.984847e-07
# ..        ...           ...           ...
# 959  0.000000           NaN           NaN
# 960  0.119819  3.165131e-08  7.322337e-09
# 961  0.037373  8.794039e-09  2.283934e-09
# 962  2.863463  2.945163e-07  1.749908e-07
# 963  0.000000  0.000000e+00  0.000000e+00
#
# [964 rows x 8 columns]

# %%
# Agrupar os dados por setor
final_database_sector_filtrada = final_database_sector.drop(['GDP', 'Population','imports','exports/pop','imports/pop'], axis=1)
setores = final_database_sector_filtrada.groupby('broad_sector')

# Classificar os grupos em ordem decrescente com base nos valores de exportação absolutos
setores_export = setores.apply(lambda x: x.nlargest(5, ['exports']))
setores_export
# Out:
#                             Country     broad_sector      exports
# broad_sector
# Agriculture     920   United States      Agriculture    72.068645
#                 96           Brazil      Agriculture    36.528111
#                 580     Netherlands      Agriculture    25.791887
#                 144          Canada      Agriculture    21.426398
#                 172           China      Agriculture    20.215533
# Mining & Energy 717          Russia  Mining & Energy   115.987843
#                 761    Saudi Arabia  Mining & Energy   104.950706
#                 41        Australia  Mining & Energy   104.522912
#                 145          Canada  Mining & Energy    61.349203
#                 409            Iraq  Mining & Energy    46.060823
# Manufacturing   174           China    Manufacturing  2262.066360
#                 922   United States    Manufacturing  1225.300472
#                 326         Germany    Manufacturing  1194.589090
#                 434           Japan    Manufacturing   702.802649
#                 454    Korea, South    Manufacturing   546.633659
# Services        923   United States         Services   609.676806
#                 327         Germany         Services   243.695300
#                 911  United Kingdom         Services   203.054463
#                 295          France         Services   183.651238
#                 583     Netherlands         Services   169.690318

# %%
# Agrupar os dados por setor
final_database_sector_filtrada = final_database_sector.drop(['GDP', 'Population','exports','exports/pop','imports/pop'], axis=1)
setores = final_database_sector_filtrada.groupby('broad_sector')

# Classificar os grupos em ordem decrescente com base nos valores de exportação absolutos
setores_export = setores.apply(lambda x: x.nlargest(5, ['imports']))
setores_export
# Out:
#                             Country     broad_sector      imports
# broad_sector
# Agriculture     920   United States      Agriculture   402.382474
#                 176          Taiwan      Agriculture   161.726022
#                 536          Mexico      Agriculture    83.889600
#                 908  United Kingdom      Agriculture    78.012073
#                 424   Cote d'Ivoire      Agriculture    71.571072
# Mining & Energy 921   United States  Mining & Energy   268.799406
#                 341          Greece  Mining & Energy    66.361577
#                 909  United Kingdom  Mining & Energy    42.484061
#                 397           India  Mining & Energy    11.213541
#                 693        Portugal  Mining & Energy     6.214357
# Manufacturing   918        Tanzania    Manufacturing  1181.681899
#                 178          Taiwan    Manufacturing   814.092370
#                 922   United States    Manufacturing   758.318544
#                 434           Japan    Manufacturing   728.398956
#                 174           China    Manufacturing   680.868555
# Services        175           China         Services   161.367592
#                 423           Italy         Services    29.478977
#                 71          Belgium         Services    24.248406
#                 295          France         Services    20.318425
#                 771          Serbia         Services    17.796969

# %%
# Agrupar os dados por setor
final_database_sector_filtrada = final_database_sector.drop(['GDP', 'Population','exports', 'imports','imports/pop'], axis=1)
setores = final_database_sector_filtrada.groupby('broad_sector')

# Classificar os grupos em ordem decrescente com base nos valores de exportação absolutos
setores_export = setores.apply(lambda x: x.nlargest(5, ['exports/pop']))
setores_export
# Out:
#                                   Country     broad_sector   exports/pop
# broad_sector
# Agriculture     580           Netherlands      Agriculture  1.514469e-06
#                 212            Costa Rica      Agriculture  7.332099e-07
#                 612           New Zealand      Agriculture  7.118574e-07
#                 68                Belgium      Agriculture  6.324726e-07
#                 40              Australia      Agriculture  6.278531e-07
# Mining & Energy 709                 Qatar  Mining & Energy  1.361889e-05
#                 457                Kuwait  Mining & Energy  7.242532e-06
#                 637                Norway  Mining & Energy  6.605637e-06
#                 869  United Arab Emirates  Mining & Energy  4.797865e-06
#                 41              Australia  Mining & Energy  4.320752e-06
# Manufacturing   154        Cayman Islands    Manufacturing  3.589804e-05
#                 782             Singapore    Manufacturing  3.522837e-05
#                 838           Switzerland    Manufacturing  3.461559e-05
#                 414               Ireland    Manufacturing  3.308574e-05
#                 498            Luxembourg    Manufacturing  2.572329e-05
# Services        75                Bermuda         Services  3.749373e-04
#                 499            Luxembourg         Services  1.437471e-04
#                 415               Ireland         Services  2.352519e-05
#                 783             Singapore         Services  1.228400e-05
#                 839           Switzerland         Services  9.980300e-06

# %%
# Agrupar os dados por setor
final_database_sector_filtrada = final_database_sector.drop(['GDP', 'Population','exports', 'exports/pop','imports'], axis=1)
setores = final_database_sector_filtrada.groupby('broad_sector')

# Classificar os grupos em ordem decrescente com base nos valores de exportação absolutos
setores_export = setores.apply(lambda x: x.nlargest(5, ['imports/pop']))
setores_export
# Out:
#                                     Country     broad_sector  imports/pop
# broad_sector
# Agriculture     240                Dominica      Agriculture     0.000102
#                 152          Cayman Islands      Agriculture     0.000032
#                 312                 Georgia      Agriculture     0.000014
#                 836             Switzerland      Agriculture     0.000007
#                 692                Portugal      Agriculture     0.000005
# Mining & Energy 153          Cayman Islands  Mining & Energy     0.000020
#                 113  British Virgin Islands  Mining & Energy     0.000014
#                 393                 Iceland  Mining & Energy     0.000012
#                 73                  Bermuda  Mining & Energy     0.000008
#                 341                  Greece  Mining & Energy     0.000006
# Manufacturing   334               Gibraltar    Manufacturing     0.004133
#                 114  British Virgin Islands    Manufacturing     0.002063
#                 394                 Iceland    Manufacturing     0.001203
#                 586                 Curacao    Manufacturing     0.001180
#                 154          Cayman Islands    Manufacturing     0.000737
# Services        795                Slovenia         Services     0.000003
#                 771                  Serbia         Services     0.000003
#                 71                  Belgium         Services     0.000002
#                 271                 Estonia         Services     0.000001
#                 395                 Iceland         Services     0.000001

# %%
# Usando os dados do ITPD-E fa¸ca uma breve an´alise da balan¸ca comercial brasileira.
# Replique a an´alise para algum outro pa´ıs, compare e comente os resultados. Vocˆe
# pode fazer a an´alise que achar mais adequada desde que apresente os dados atrav´es de
# gr´aficos e/ou tabelas.

# %%
itpd_brazil = itpd_ie_sector[itpd_ie_sector['Country'] == 'Brazil']
itpd_brazil
# Out:
#    Country     broad_sector     exports    imports  trade_balance  \
# 96  Brazil      Agriculture   36.528111   0.952094      35.576017
# 97  Brazil  Mining & Energy   38.023374   0.213123      37.810252
# 98  Brazil    Manufacturing  125.370414  29.411638      95.958777
# 99  Brazil         Services   16.572157   7.608932       8.963226
#
#     total_commerce
# 96       37.480204
# 97       38.236497
# 98      154.782052
# 99       24.181089

# %%
total_export = itpd_brazil['exports'].sum()
total_export
# Out:
# 216.49405667729002

# %%
itpd_brazil['% Sector in Total Exports'] = (itpd_brazil['exports']/total_export) * 100
itpd_brazil
# Out:
# C:\Users\pedro\AppData\Local\Temp\ipykernel_23456\1699969350.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#    Country     broad_sector     exports    imports  trade_balance  \
# 96  Brazil      Agriculture   36.528111   0.952094      35.576017
# 97  Brazil  Mining & Energy   38.023374   0.213123      37.810252
# 98  Brazil    Manufacturing  125.370414  29.411638      95.958777
# 99  Brazil         Services   16.572157   7.608932       8.963226
#
#     total_commerce  % Sector in Total Exports
# 96       37.480204                  16.872570
# 97       38.236497                  17.563242
# 98      154.782052                  57.909402
# 99       24.181089                   7.654786

# %%
# Set the figure size
plt.figure(figsize=(8, 8))

# Create the pie chart
plt.pie(itpd_brazil['% Sector in Total Exports'], labels=itpd_brazil['broad_sector'], autopct='%1.1f%%')

# Add a title
plt.title('% Sector in Total Exports for Brazil')

# Show the chart
plt.show()

# %%
total_import = itpd_brazil['imports'].sum()
itpd_brazil['% Sector in Total Imports'] = (itpd_brazil['imports']/total_export) * 100

# Set the figure size
plt.figure(figsize=(8, 8))

# Create the pie chart
plt.pie(itpd_brazil['% Sector in Total Imports'], labels=itpd_brazil['broad_sector'], autopct='%1.1f%%')

# Add a title
plt.title('% Sector in Total Imports for Brazil')

# Show the chart
plt.show()
# Out:
# C:\Users\pedro\AppData\Local\Temp\ipykernel_23456\3317631105.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
itpd_india = itpd_ie_sector[itpd_ie_sector['Country'] == 'India']
itpd_india
# Out:
#     Country     broad_sector     exports     imports  trade_balance  \
# 396   India      Agriculture   11.044097   42.605351     -31.561253
# 397   India  Mining & Energy    5.162236   11.213541      -6.051304
# 398   India    Manufacturing  246.942482  270.801493     -23.859011
# 399   India         Services   42.251155    0.908303      41.342852
#
#      total_commerce
# 396       53.649448
# 397       16.375777
# 398      517.743975
# 399       43.159458

# %%
total_export_india = itpd_india['exports'].sum()
total_export_india
# Out:
# 305.39997096706

# %%
itpd_india['% Sector in Total Exports'] = (itpd_india['exports']/total_export_india) * 100
itpd_india
# Out:
# C:\Users\pedro\AppData\Local\Temp\ipykernel_23456\20745376.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#     Country     broad_sector     exports     imports  trade_balance  \
# 396   India      Agriculture   11.044097   42.605351     -31.561253
# 397   India  Mining & Energy    5.162236   11.213541      -6.051304
# 398   India    Manufacturing  246.942482  270.801493     -23.859011
# 399   India         Services   42.251155    0.908303      41.342852
#
#      total_commerce  % Sector in Total Imports  % Sector in Total Exports
# 396       53.649448                  19.679686                   3.616273
# 397       16.375777                   5.179607                   1.690320
# 398      517.743975                 125.084955                  80.858712
# 399       43.159458                   0.419551                  13.834695

# %%
# Set the figure size
plt.figure(figsize=(8, 8))

# Create the pie chart
plt.pie(itpd_india['% Sector in Total Exports'], labels=itpd_india['broad_sector'], autopct='%1.1f%%')

# Add a title
plt.title('% Sector in Total Exports for India')

# Show the chart
plt.show()

# %%
total_imports_india = itpd_india['imports'].sum()
itpd_india['% Sector in Total Imports'] = (itpd_india['imports']/total_export) * 100

# Set the figure size
plt.figure(figsize=(8, 8))

# Create the pie chart
plt.pie(itpd_india['% Sector in Total Imports'], labels=itpd_india['broad_sector'], autopct='%1.1f%%')

# Add a title
plt.title('% Sector in Total Imports for India')

# Show the chart
plt.show()
# Out:
# C:\Users\pedro\AppData\Local\Temp\ipykernel_23456\1330814168.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
